# %%
import pandas

data = pandas.read_csv("datasets/supermarket_data.csv")
data
# Out:
#        Invoice ID     city customertype  gender                 product  \
# 0     750-67-8428  Nairobi       Member  Female       Health and beauty
# 1     226-31-3081   Nakuru       Normal  Female  Electronic accessories
# 2     631-41-3108  Nairobi       Normal  Female      Home and lifestyle
# 3     123-19-1176  Nairobi       Member  Female       Health and beauty
# 4     373-73-7910  Nairobi       Normal  Female       Health and beauty
# ...           ...      ...          ...     ...                     ...
# 996   233-67-5758   Nakuru       Normal    Male       Health and beauty
# 997   303-96-2227  Mombasa       Normal  Female      Home and lifestyle
# 998   727-02-1313  Nairobi       Member    Male      Food and beverages
# 999   347-56-2442  Nairobi       Normal    Male      Home and lifestyle
# 1000  849-09-3807  Nairobi       Member  Female     Fashion accessories
#
#       itemprice  quantity      total       date   time      payment  \
# ...

# %%
# Use the describe function
data.describe()
# gives dirty data which may lead to errors during analysis
# Out:
#         itemprice     quantity        total  customersalary       rating
# count  998.000000  1001.000000  1001.000000     1001.000000  1001.000000
# mean    55.686523     5.505495   322.739927       15.368568     6.972527
# std     26.538665     2.925444   245.867115       11.707958     1.717729
# min     10.080000     1.000000    10.678500        0.508500     4.000000
# 25%     32.825000     3.000000   122.524500        5.834500     5.500000
# 50%     55.230000     5.000000   253.680000       12.080000     7.000000
# 75%     78.040000     8.000000   471.030000       22.430000     8.500000
# max     99.960000    10.000000  1042.650000       49.650000    10.000000

# %%
# Three rows(1001-998=3) are empty in the itemprices column
# They need to be filled by a value which will be the column mean
data["itemprice"] = data["itemprice"].fillna(55)

# describe the data again
data.describe()
# Out:
#          itemprice     quantity        total  customersalary       rating
# count  1001.000000  1001.000000  1001.000000     1001.000000  1001.000000
# mean     55.684466     5.505495   322.739927       15.368568     6.972527
# std      26.498854     2.925444   245.867115       11.707958     1.717729
# min      10.080000     1.000000    10.678500        0.508500     4.000000
# 25%      32.900000     3.000000   122.524500        5.834500     5.500000
# 50%      55.040000     5.000000   253.680000       12.080000     7.000000
# 75%      77.950000     8.000000   471.030000       22.430000     8.500000
# max      99.960000    10.000000  1042.650000       49.650000    10.000000

# %%
# To accurately count the blanks
# print(data["customertype"].isnull().sum())

# View the specific problematic rows
# data[data["customertype"].isnull()]

# To include the blanks, the (Get the number of entries in  given column) function
# data.groupby("customertype").size()
# Is overwritten by:
data.groupby("customertype", dropna=False).size()
# Out:
# customertype
# Member    500
# Normal    495
# NaN         6
# dtype: int64

# %%
# Combining multiple columns
data.groupby(["city","payment"]).size()
# Out:
# city     payment
# Mombasa  Cash            73
#          Credit card     83
#          MPESA          144
# Nairobi  Cash           118
#          Credit card     98
#          MPESA          179
# Nakuru   Cash            84
#          Credit card     74
#          MPESA          148
# dtype: int64

# %%
# Import the modules 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Below is a count plot showing the description of males  to females
sns.countplot(x="gender", data=data, palette="summer")
plt.title("Gender Distribution Against Total Count")
plt.ylabel("Total Count of Individuals")
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_14820\2718994788.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="gender", data=data, palette="summer")
# Text(0, 0.5, 'Total Count of Individuals')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# 1. Create the plot and assign it to 'ax'
ax = sns.countplot(x="gender", data=data, palette="autumn")
# 2. Add labels to each bar container
for container in ax.containers:
    ax.bar_label(container)
# 3. Rest of your formatting
plt.title("Gender Distribution Against Total Count")
plt.ylabel("Total Count of Individuals")
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_14820\986732258.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x="gender", data=data, palette="autumn")

# %%
# 1. Get the total count of the data
total = len(data['gender'])
# 2. Create the plot
ax = sns.countplot(x="gender", data=data, palette="spring")
# 3. Calculate percentages and add them as labels
for container in ax.containers:
    # Create labels: (bar height / total) * 100
    labels = [f'{(v/total)*100:0.1f}%' for v in container.datavalues]
    ax.bar_label(container, labels=labels, padding=3)
plt.title("Gender Distribution (Percentage)")
plt.ylabel("Total Count")
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_14820\1248423343.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x="gender", data=data, palette="spring")

# %%
# Below is a countplot that has two columns
sns.countplot(x="gender", hue="city", palette="Reds", data=data)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
# Below is a pieplot
# %1.(n)f%% - The number occupying the n part is the number of decimal places to be used on the piechart
data["payment"].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: >
